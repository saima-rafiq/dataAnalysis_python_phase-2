# %%
import pandas as pd
import numpy as np

# %%
review=pd.read_csv("winemag-data-130k-v2.csv")
review
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
# remove un-named column
review=pd.read_csv("winemag-data-130k-v2.csv",index_col=0)
review.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# fetch a specific column
review.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
review['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
# fetch all column without dots
pd.set_option('display.max_rows', 6)

# Print the DataFrame
print(review)
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# ...                               ...     ...    ...                ...
# ...

# %% [markdown]
# # index based selection

# %%
pd.set_option('display.max_columns',None)

review
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# ...                               ...     ...    ...                ...
# ...

# %%
# 0:3 means range of  rows and 0 column
review.iloc[0:3,0]  
review.iloc[0:3]
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
# based on labled index
review.loc[0,'country']
# Out:
# 'Italy'

# %% [markdown]
# # conditional selecting

# %%
review.country=='italy'
# Out:
# 0         False
# 1         False
# 2         False
#           ...
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
review.loc[review.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# ...        ...                                                ...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                         Belsito      87   16.0  Sicily & Sardinia
# 13                          Rosso      87    NaN  Sicily & Sardinia
# ...                           ...     ...    ...                ...
# 129947                   Symposio      90   20.0  Sicily & Sardinia
# ...

# %%
review.loc[(review.country == 'Italy') | (review.country == 'US')]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129967      US  Citation is given as much as a decade of bottl...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# 2                             NaN      87   14.0             Oregon
# 3            Reserve Late Harvest      87   13.0           Michigan
# ...                           ...     ...    ...                ...
# 129961                        NaN      90   30.0  Sicily & Sardinia
# ...

# %%
review.loc[review.country.isin(['Italy','France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# ...        ...                                                ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 7                                 NaN      87   24.0             Alsace
# ...                               ...     ...    ...                ...
# 129968                          Kritt      90   30.0             Alsace
# ...

# %%
# Assuming 'df' is your DataFrame
review1 = review.isnull().sum()
print(review1)
# Out:
# country           63
# description        0
# designation    37465
#                ...
# title              0
# variety            1
# winery             0
# Length: 13, dtype: int64

# %%
review2=review.loc[review.price.isnull()]
print(review2)
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# ...          ...                                                ...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# 13                             Rosso      87    NaN  Sicily & Sardinia
# 30                           Nouveau      86    NaN         Beaujolais
# ...                              ...     ...    ...                ...
# ...

# %%
review2=review.loc[review.price.notnull()]
print(review2)
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# ...          ...                                                ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price  province  \
# 1                            Avidagos      87   15.0     Douro
# 2                                 NaN      87   14.0    Oregon
# 3                Reserve Late Harvest      87   13.0  Michigan
# ...                               ...     ...    ...       ...
# 129968                          Kritt      90   30.0    Alsace
# ...

# %% [markdown]
# # exporting values to csv/saved altered file in csv

# %%
# load the origional dataset
wine_review="winemag-data-130k-v2.csv"
read=pd.read_csv(wine_review)
# ranodom selected rows
selected_rows=read.sample(n=1000,random_state=42)
# save selected rows
selected_rows.to_csv('wine_review.csv',index=False)
print(selected_rows)
# Out:
#         Unnamed: 0    country  \
# 77718        77718  Australia
# 67681        67681     France
# 69877        69877      Spain
# ...            ...        ...
# 43282        43282         US
# 4577          4577     France
# 128329      128329      Italy
#
#                                               description  \
# 77718   Possibly a little sweet, this is a soft, easyg...
# 67681   A soft, almost off dry wine that is full in th...
# 69877   Generic white-fruit aromas of peach and apple ...
# ...                                                   ...
# 43282   This is a soft vineyard-designate, approachabl...
# 4577    The Birot estate is in Cadillac, the fortress ...
# 128329  Here's a riserva Brunello that opens with inky...
#
#                    designation  points  price         province  \
# 77718                      NaN      83    5.0  Australia Other
# 67681                  Réserve      85   12.0     Rhône Valley
# ...

# %%
wine_review=pd.read_csv("wine_review.csv")

wine_review.shape
# Out:
# (1000, 14)

# %% [markdown]
# # assigning data

# %%
review['critic']='everyone'
review['critic']
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
#             ...
# 129968    everyone
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object
